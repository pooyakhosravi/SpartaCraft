# %% [markdown]
# ### Imports

# %%
import numpy as np
import tensorflow as tf
import logging
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import gym
import numpy as np
from IPython import display
import matplotlib
import time

import DQN_Agent
import tile_coding
import Utils
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Normal Q Learning

# %%
agent = DQN_Agent.Discrete(gym.make('FrozenLake-v0'))
j_list, r_list = agent.train(20000)

print("Final Q-Table Values")
print(agent.Q)

result = sum(r_list)/len(r_list)
print(f"Score over time: {result}")
# Out:
# ...
# Final Q-Table Values
# [[4.38376480e-01 4.08248034e-03 3.31114242e-03 4.13744700e-03]
#  [5.31695873e-04 7.37227099e-04 6.45716667e-04 2.46610938e-01]
#  [1.64347916e-03 1.42054375e-01 3.09440543e-03 2.97036464e-03]
#  [6.16523805e-04 2.61949154e-05 1.01094003e-04 5.63456329e-02]
#  [2.84560149e-01 5.20992380e-04 2.95117312e-03 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [2.82613153e-02 1.83943959e-06 1.04918559e-06 2.40445556e-05]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.44309622e-03 1.22213507e-03 0.00000000e+00 5.51112536e-01]
#  [0.00000000e+00 3.80970606e-01 6.90484800e-04 0.00000000e+00]
#  [8.06835852e-01 7.33779954e-05 1.34229567e-05 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 4.92905160e-03 7.83706220e-01 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 9.65791456e-01]
# ...

# %%
Utils.graph_results(j_list, r_list)

# %% [markdown]
# ### Deep Q Learning

# %%
agent = DQN_Agent.DeepDiscrete(gym.make('FrozenLake-v0'))
j_list, r_list = agent.train(2000)
# Out:
# ...
# Percent of succesful episodes: 4.75%

# %%
Utils.graph_results(j_list, r_list)

# %% [markdown]
# ### Deep Q-Learning with Continuous States

# %%
agent = DQN_Agent.DeepContinuous(gym.make('MountainCar-v0'))
j_list, r_list = agent.train(2000)
Utils.graph_results(j_list, r_list)
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-c0c3cb426280> in <module>
#       1 agent = DQN_Agent.DeepContinuous(gym.make('MountainCar-v0'))
# ----> 2 j_list, r_list = agent.train(2000)
#       3 Utils.graph_results(j_list, r_list)
#
# ~/dev/SpartaCraft/DQN_Agent.py in train(self, num_episodes, max_steps)
#     204                         e = 1./((i/50) + 10)
#     205                         break
# --> 206                 self.replay(32)
#     207             print("Percent of succesful episodes: " + str(sum(reward_list)/num_episodes * 100) + "%")
#     208             return reward_list, num_steps_list
#
# ~/dev/SpartaCraft/DQN_Agent.py in replay(self, batch_size)
#     175             if not done:
#     176               target = reward + self.gamma * \
# --> 177                        np.amax(self.model.predict(next_state, steps=1)[0])
# ...

# %%
env = gym.make('MountainCar-v0')

# %%
env.observation_space.shape
# Out:
# (2,)
